# %%
# !nvidia-smi
# !ls -R /kaggle/input | head -20
# Out:
# Wed Sep  9 15:04:22 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.159.04             Driver Version: 580.159.04     CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   33C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
DATA = '/kaggle/input/datasets/bornamuzina/dataset2/yolo_rgb_k/yolo_rgb'
# !ls {DATA}
# Out:
# data.yaml  images  labels

# %%
yaml = f"""path: {DATA}
train: images/train
val: images/val
test: images/test

names:
  0: drone
"""
open('/kaggle/working/data.yaml','w').write(yaml)
# !cat /kaggle/working/data.yaml
# Out:
# path: /kaggle/input/datasets/bornamuzina/dataset2/yolo_rgb_k/yolo_rgb
# train: images/train
# val: images/val
# test: images/test
#
# names:
#   0: drone

# %%
# !pip install -q ultralytics
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.4/46.4 kB 2.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 30.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.4/75.4 kB 6.1 MB/s eta 0:00:00

# %%
# !yolo detect train data=/kaggle/working/data.yaml model=yolo26n.pt imgsz=224 epochs=50 batch=64 project=/kaggle/working/runs name=yolo26_rgb
# Out:
# Creating new Ultralytics Settings v0.0.8 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart#ultralytics-settings.
# ...
# Ultralytics 8.4.145 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# ...

# %%
# !yolo detect val data=/kaggle/working/data.yaml model=/kaggle/working/runs/yolo26_rgb-2/weights/best.pt imgsz=224 split=val
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#              ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/cfg/__init__.py", line 1121, in entrypoint
#     model = YOLO(model, task=task)
#             ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/models/yolo/model.py", line 83, in __init__
#     super().__init__(model=model, task=task, verbose=verbose)
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py", line 133, in __init__
#     self._load(model, task=task)
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py", line 250, in _load
#     self.model, self.ckpt = load_checkpoint(weights)
#                             ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/nn/tasks.py", line 1957, in load_checkpoint
# ...

# %%
# !cd /kaggle/working && zip -qr yolo26_rgb.zip runs/yolo26_rgb-2
# !ls -lh /kaggle/working/yolo26_rgb.zip
# Out:
# zip error: Nothing to do! (try: zip -qr yolo26_rgb.zip . -i runs/yolo26_rgb-2)
# ls: cannot access '/kaggle/working/yolo26_rgb.zip': No such file or directory
